# %% [markdown]
# # ISM6251.003S23- Assignment 2
#
#
# ## Business Problem
# The aim is to create a predictive model using the patient characteristics provided, which can determine if a patient has heart disease or not. If the model proves effective, it could be utilized by the medical sector to anticipate heart disease in new patients who possess the necessary data. This will enable them to prioritize patients for diagnostic testing, surgeries, and other treatments.
#
# ## Description of the analysis
# This project aims to determine the evaluation metrics employed for assessing the performance of the model(s) and explain the rationale behind the selection of these metrics. The logistic regression, SVM, and decision tree model, MLP and Keras technique will be utilized for modeling purposes. To test a variety of parameter values for each model, both random and grid searches will be performed for each of the model.

# %% [markdown]
# ### 1. Library Import

# %%
import numpy as np
import pandas as pd
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from keras.initializers import GlorotNormal

# %% [markdown]
# ### 2. Load the data

# %%
X_train = pd.read_csv("heart_train_X.csv")
X_test = pd.read_csv("heart_test_X.csv")
y_train = pd.read_csv("heart_train_y.csv")
y_test = pd.read_csv("heart_test_y.csv")

# %% [markdown]
# ### 2.1 Model the data
#
# Dataframe will be constructed to contain all the outcomes obtained from our models

# %%
performance = pd.DataFrame({"model": [], "Accuracy": [], "Precision": [], "Recall": [], "F1": []})

# %% [markdown]
# ### 3. Choosing the right performance metric
#
# In this dataset, a false-negative result would indicate that a person with heart disease is wrongly classified as healthy. Therefore, it is crucial to choose a model that minimizes the number of false negatives and thus, maximizes the recall value. Also, the cost of a false-negative result in this model is very high and would result in death of the patient.
#
# Hence, recall will be used to measure the performance of the models.

# %% [markdown]
# ### 4. Logistic Regression

# %% [markdown]
# #### 4.1 Define parameter distribution

# %%
param_grid_lr = {'penalty': ['None','l1', 'l2']}

# %% [markdown]
# #### 4.2 Performing Random Search

# %%
#Defining scoring metric
score_measure = "recall"

# define the logistic regression model
model = LogisticRegression()

# Create a random search object
random_search_lr = RandomizedSearchCV(estimator=model, param_distributions=param_grid_lr, n_iter=100, cv=5, random_state=42)

# Fit the random search to the data
_ = random_search_lr.fit(X_train, y_train)

# Print the best parameters found
print(f"The best {score_measure} score is {random_search_lr.best_score_}")
print(f"... with parameters: {random_search_lr.best_params_}")

warnings.filterwarnings('ignore')
# Out:
# The best recall score is 0.8243968739381582
# ... with parameters: {'penalty': 'l2'}

# %% [markdown]
# #### 4.3 Grid Search

# %%
#Defining scoring metric
score_measure = "recall"
kfolds = 5

#Using best parameters found from random search
param_grid_lrg = {'penalty': ['l2']}

# define the logistic regression model
model = LogisticRegression()

# define the grid search
grid_search_lr = GridSearchCV(estimator = model, param_grid=param_grid_lrg, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

# fit the grid search to the data
_ = grid_search_lr.fit(X_train, y_train)


#Best parameters
print(f"Best parameters: {grid_search_lr.best_params_}")
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Best parameters: {'penalty': 'l2'}

# %% [markdown]
# #### 4.4 Predict with test data

# %%
c_matrix = confusion_matrix(y_test, grid_search_lr.predict(X_test))
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]

performance = pd.concat([performance, pd.DataFrame({'model':"Logistic Regression", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])
performance
# Out:
#                  model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.772532   0.803571  0.743802  0.772532

# %% [markdown]
# ### 5. SVM

# %% [markdown]
# #### 5.1 Define parameter distribution

# %%
param_grid_SVM = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

# %% [markdown]
# #### 5.2  Performing Random Search

# %%
# Create an SVM classifier
svm = SVC()

# Create a random search object
random_search_SVM = RandomizedSearchCV(
    svm, 
    param_distributions=param_grid_SVM, 
    n_iter=50, # number of parameter combinations to try
    cv=5, # number of cross-validation folds
    scoring='recall', # scoring metric to use
    verbose=1, 
    n_jobs=-1 # number of CPU cores to use for parallel computation
)


# Fit the random search to the data
_= random_search_SVM.fit(X_train, y_train)

# Print the best parameters found
print("Best parameters found:", random_search_SVM.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters found: {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1}

# %% [markdown]
# #### 5.3 Grid Search

# %%
#Using the best parameters found from random search
param_grid_SVMg = [
  {'C': [1], 
   'kernel': ['rbf'],
   'gamma': [0.0001]}
  
]

# Create an SVM classifier
svm = SVC()

# Create a grid search object
grid_search_SVM = GridSearchCV(
    svm, 
    param_grid=param_grid_SVMg, 
    cv=5, # number of cross-validation folds
    scoring='recall', # scoring metric to use
    verbose=1, 
    n_jobs=-1 # number of CPU cores to use for parallel computation
)

# Fit the grid search to the data
grid_search_SVM.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid=[{'C': [1], 'gamma': [0.0001], 'kernel': ['rbf']}],
#              scoring='recall', verbose=1)

# %%
c_matrix = confusion_matrix(y_test, grid_search_SVM.predict(X_test))
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]

performance = pd.concat([performance, pd.DataFrame({'model':"SVM", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])
performance
# Out:
#                  model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.772532   0.803571  0.743802  0.772532
# 0                  SVM  0.519313   0.519313  1.000000  0.683616

# %% [markdown]
# ### 6. Decision Tree

# %% [markdown]
# #### 6.1 Define Parameter Distribution

# %%
param_grid_dtree = {
    'min_samples_split': np.arange(1,200),  
    'min_samples_leaf': np.arange(1,200),
    'max_leaf_nodes': np.arange(5, 200), 
    'max_depth': np.arange(1,50), 
    'criterion': ['entropy', 'gini'],
}

# %% [markdown]
# #### 6.2 Perform Random Search

# %%
# Define scoring measure
score_measure = "recall"
kfolds = 5

# Create a decision tree object
dtree = DecisionTreeClassifier()

# Use RandomizedSearchCV to search over the parameter grid
random_search_dtree = RandomizedSearchCV(estimator = dtree, param_distributions=param_grid_dtree, cv=kfolds, n_iter=500,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

# Fit the random search object to the data
_ = random_search_dtree.fit(X_train, y_train)

# Print the best parameters and score

print(f"The best {score_measure} score is {random_search_dtree.best_score_}")
print(f"... with parameters: {random_search_dtree.best_params_}")


warnings.filterwarnings('ignore')
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# The best recall score is 0.8442857142857143
# ... with parameters: {'min_samples_split': 161, 'min_samples_leaf': 27, 'max_leaf_nodes': 179, 'max_depth': 12, 'criterion': 'gini'}

# %% [markdown]
# #### 6.3 Grid Search

# %%
#Define scoring measure
score_measure = "recall"
kfolds = 5

#Using best parameters found from random search
param_grid_dtreeg = {
    'min_samples_split': np.arange(176,180),  
    'min_samples_leaf': np.arange(22,26),
    'max_leaf_nodes': np.arange(49,53), 
    'max_depth': np.arange(20,24), 
    'criterion': ['gini'],
}

# Create a decision tree object
dtree = DecisionTreeClassifier()

# Create a grid search object
grid_search_dtree = GridSearchCV(estimator = dtree, param_grid=param_grid_dtreeg, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

# Fit the grid search to the data
_ = grid_search_dtree.fit(X_train, y_train)


# Print the best parameters and score
print(f"The best {score_measure} score is {grid_search_dtree.best_score_}")
print(f"... with parameters: {grid_search_dtree.best_params_}")
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# The best recall score is 0.8442857142857143
# ... with parameters: {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 49, 'min_samples_leaf': 23, 'min_samples_split': 176}

# %%
c_matrix = confusion_matrix(y_test, grid_search_dtree.predict(X_test))
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"Decision tree", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])
performance
# Out:
#                  model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.772532   0.803571  0.743802  0.772532
# 0                  SVM  0.519313   0.519313  1.000000  0.683616
# 0        Decision tree  0.738197   0.720588  0.809917  0.762646

# %% [markdown]
# ### 7 MLP

# %% [markdown]
# #### 7.1 Define parameter distribution

# %%
param_distributions_MLP = {
    'hidden_layer_sizes': [ (64,), (128,),(128,64), (64,128), (64,128,196), (196,128,64)],
    'activation': ['logistic', 'tanh', 'relu'],
    'solver': ['adam', 'sgd'],
    'alpha': [0, .0001, .0005, .001, .005],
    'batch_size': [25, 50, 100],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'learning_rate_init': [0.0005, 0.001, 0.005, 0.01],
    'max_iter': [5000],
    'tol': [0.000005, 0.00001, 0.00005],
    'early_stopping':[True],
    'n_iter_no_change':[5],
}

# %% [markdown]
# #### 7.2 Perform Random search

# %%
#Defining Scoring metric
score_measure = "recall"
kfolds = 5

#Create a MLP classifier
ann = MLPClassifier()

#Use RandomizedSearchCV to search over the parameter grid
random_search_MLP = RandomizedSearchCV(estimator = ann, param_distributions=param_distributions_MLP, cv=kfolds, n_iter=100,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)
# Fit the random search object to the data
_ = random_search_MLP.fit(X_train, y_train)

# Print the best parameters and score
bestRecallTree = random_search_MLP.best_estimator_
print(random_search_MLP.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'tol': 5e-06, 'solver': 'sgd', 'n_iter_no_change': 5, 'max_iter': 5000, 'learning_rate_init': 0.01, 'learning_rate': 'constant', 'hidden_layer_sizes': (196, 128, 64), 'early_stopping': True, 'batch_size': 50, 'alpha': 0.001, 'activation': 'logistic'}

# %%
y_pred = bestRecallTree.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       112
#            1       0.52      1.00      0.68       121
#
#     accuracy                           0.52       233
#    macro avg       0.26      0.50      0.34       233
# weighted avg       0.27      0.52      0.36       233

# %% [markdown]
# #### 7.3 Grid Search

# %%
#Define scoring measure
score_measure = "recall"
kfolds = 5

#Using best parameters found from random search
param_grid_MLPg = {
    'hidden_layer_sizes': [(196,128,64)],
    'activation': ['logistic'],
    'solver': ['sgd'],
    'alpha': [0.001],
    'learning_rate': ['constant'],
    'learning_rate_init': [0.01],
    'max_iter': [5000]
}

#Create a MLP classifier
ann = MLPClassifier()

# Create a grid search object
grid_search_MLP = GridSearchCV(estimator = ann, param_grid=param_grid_MLPg, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

# Fit the grid search to the data
_ = grid_search_MLP.fit(X_train, y_train)

# Print the best parameters and score
bestRecallTree = grid_search_MLP.best_estimator_

print(grid_search_MLP.best_params_)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (196, 128, 64), 'learning_rate': 'constant', 'learning_rate_init': 0.01, 'max_iter': 5000, 'solver': 'sgd'}

# %%
y_pred = bestRecallTree.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       112
#            1       0.52      1.00      0.68       121
#
#     accuracy                           0.52       233
#    macro avg       0.26      0.50      0.34       233
# weighted avg       0.27      0.52      0.36       233

# %%
c_matrix = confusion_matrix(y_test, grid_search_MLP.predict(X_test))
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"MLP", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])
performance
# Out:
#                  model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.772532   0.803571  0.743802  0.772532
# 0                  SVM  0.519313   0.519313  1.000000  0.683616
# 0        Decision tree  0.738197   0.720588  0.809917  0.762646
# 0                  MLP  0.519313   0.519313  1.000000  0.683616

# %% [markdown]
# ### 8. Keras techniques

# %%
# create model structure
def build_clf(meta, hidden_layer_sizes, dropout):
    n_features_in_ = meta["n_features_in_"]
    n_classes_ = meta["n_classes_"]
    target_encoder_ = meta["target_encoder_"]
    
    model = tf.keras.models.Sequential()
    model.add(keras.layers.Input(shape=n_features_in_)),
    #for hidden_layer_size in hidden_layer_sizes:
    for hidden_layer_size in hidden_layer_sizes:
        model.add(keras.layers.Dense(hidden_layer_size, 
            kernel_initializer= tf.keras.initializers.GlorotUniform(), 
            bias_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None), 
            activation="relu"))
        model.add(keras.layers.Dropout(dropout))
    model.add(tf.keras.layers.Dense(10, activation='sigmoid'))
    
    

    return model

# %%
from scikeras.wrappers import KerasClassifier

keras_clf = KerasClassifier(
    model=build_clf,
    hidden_layer_sizes=64,
    dropout=0.5,
    optimizer=keras.optimizers.Adam,
    optimizer__learning_rate=0.0001
)
keras_clf.get_params()
# Out:
# {'model': <function __main__.build_clf(meta, hidden_layer_sizes, dropout)>,
#  'build_fn': None,
#  'warm_start': False,
#  'random_state': None,
#  'optimizer': keras.optimizers.optimizer_v2.adam.Adam,
#  'loss': None,
#  'metrics': None,
#  'batch_size': None,
#  'validation_batch_size': None,
#  'verbose': 1,
#  'callbacks': None,
#  'validation_split': 0.0,
#  'shuffle': True,
#  'run_eagerly': False,
#  'epochs': 1,
#  'hidden_layer_sizes': 64,
#  'dropout': 0.5,
#  'optimizer__learning_rate': 0.0001,
#  'class_weight': None}

# %% [markdown]
# #### 8.1 Define parameters

# %%
params = {
    
    
    'model__hidden_layer_sizes': [(70,),(90, ), (100,), (100, 90)], 
    'model__dropout': [0, 0.1],
    'batch_size':[20, 60, 100],
    'epochs':[10],
    'optimizer':['adam','sgd'],
    'loss':['sparse_categorical_crossentropy'],
    
    # this is added to the optimizer 
    'optimizer__learning_rate': [0.0001, 0.001, 0.01]

}
keras_clf.get_params()
# Out:
# {'model': <function __main__.build_clf(meta, hidden_layer_sizes, dropout)>,
#  'build_fn': None,
#  'warm_start': False,
#  'random_state': None,
#  'optimizer': keras.optimizers.optimizer_v2.adam.Adam,
#  'loss': None,
#  'metrics': None,
#  'batch_size': None,
#  'validation_batch_size': None,
#  'verbose': 1,
#  'callbacks': None,
#  'validation_split': 0.0,
#  'shuffle': True,
#  'run_eagerly': False,
#  'epochs': 1,
#  'hidden_layer_sizes': 64,
#  'dropout': 0.5,
#  'optimizer__learning_rate': 0.0001,
#  'class_weight': None}

# %% [markdown]
# #### 8.2 Perform Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

rnd_search_cv = RandomizedSearchCV(
    estimator=keras_clf, 
    param_distributions=params, 
    scoring='recall',  
    n_iter=50, 
    cv=3)

_ = rnd_search_cv.fit(X_train, y_train,  verbose=1)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 3ms/step - loss: 2.3085
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0631
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.8377
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.6262
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4322
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2601
# Epoch 7/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1073
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9756
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8670
# Epoch 10/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7760
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4540
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1652
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9076
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6766
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4688
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2838
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1220
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9866
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8745
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7826
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5632
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2311
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9479
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6915
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4670
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2764
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1214
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9893
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8813
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7925
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1622
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9761
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7982
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6314
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4750
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3335
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2100
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0992
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0024
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9257
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1866
# Epoch 2/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0327
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8781
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7443
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5998
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4739
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3578
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2366
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1342
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0413
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FD61144C10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3281
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1518
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9822
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8282
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6742
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5241
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3971
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2838
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1686
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0630
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FD61146170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 18/18 [==============================] - 1s 2ms/step - loss: 0.7160
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4565
# Epoch 3/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4090
# Epoch 4/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3843
# Epoch 5/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3626
# Epoch 6/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3507
# Epoch 7/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3318
# Epoch 8/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3337
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3307
# Epoch 10/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3238
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 0.7207
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4262
# Epoch 3/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4298
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4973
# Epoch 5/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4019
# Epoch 6/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3540
# Epoch 7/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3507
# Epoch 8/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3434
# Epoch 9/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3278
# Epoch 10/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3216
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 0.7742
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4954
# Epoch 3/10
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4354
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3924
# Epoch 5/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3604
# Epoch 6/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3489
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3486
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3868
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3579
# Epoch 10/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4086
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 18/18 [==============================] - 1s 2ms/step - loss: 0.8667
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4327
# Epoch 3/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4080
# Epoch 4/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3875
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4127
# Epoch 6/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4217
# Epoch 7/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3872
# Epoch 8/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3480
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3438
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3379
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 0.7738
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4142
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3736
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3763
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3888
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3856
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3580
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3573
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3595
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3876
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 0.8681
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4175
# Epoch 3/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4136
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3888
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3687
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3695
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3640
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4626
# Epoch 9/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3533
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3449
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 18/18 [==============================] - 0s 2ms/step - loss: 2.2724
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 1.7094
# Epoch 3/10
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2935
# Epoch 4/10
# 18/18 [==============================] - 0s 3ms/step - loss: 0.9646
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7600
# Epoch 6/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6391
# Epoch 7/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5641
# Epoch 8/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5300
# Epoch 9/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4981
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4772
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 2ms/step - loss: 2.3948
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.7949
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.3357
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9884
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7660
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6289
# Epoch 7/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5415
# Epoch 8/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4914
# Epoch 9/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4570
# Epoch 10/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4477
# 9/9 [==============================] - 0s 1000us/step
# Epoch 1/10
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0432
# Epoch 2/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.4766
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.0774
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8170
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6691
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5986
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5494
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5131
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4917
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4708
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 4ms/step - loss: 2.6900
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.6623
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.6347
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.6073
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.5806
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.5536
# Epoch 7/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.5270
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.5006
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4740
# Epoch 10/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4480
# 4/4 [==============================] - 0s 3ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4568
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4239
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3932
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3634
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3347
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3059
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2773
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2493
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2214
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1936
# 3/3 [==============================] - 0s 0s/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4888
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4568
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4268
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3973
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3687
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3401
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3116
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2835
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2551
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2274
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7147
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 1.3098
# Epoch 3/10
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0069
# Epoch 4/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8141
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6945
# Epoch 6/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6208
# Epoch 7/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5725
# Epoch 8/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5392
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5159
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4972
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 2.1131
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.5998
# Epoch 3/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.1858
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.9079
# Epoch 5/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7409
# Epoch 6/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6341
# Epoch 7/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5684
# Epoch 8/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5252
# Epoch 9/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4956
# Epoch 10/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4774
# 9/9 [==============================] - 0s 3ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0288
# Epoch 2/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.5048
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.1032
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8550
# Epoch 5/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.7162
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6269
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5692
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5326
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5072
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4875
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0263
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 1.5439
# Epoch 3/10
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2074
# Epoch 4/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.9852
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8399
# Epoch 6/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7437
# Epoch 7/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6773
# Epoch 8/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6292
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5942
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5679
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 2ms/step - loss: 2.2387
# Epoch 2/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.7123
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.3307
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.0600
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8827
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7587
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6776
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6177
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5743
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5465
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 1ms/step - loss: 2.2058
# Epoch 2/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.6411
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.2570
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.0179
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8588
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7564
# Epoch 7/10
# 19/19 [==============================] - 0s 804us/step - loss: 0.6866
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6376
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6026
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5767
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3846
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3632
# Epoch 3/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.3490
# Epoch 4/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.3317
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3234
# Epoch 6/10
# 6/6 [==============================] - 0s 883us/step - loss: 2.3107
# Epoch 7/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2909
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2762
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2632
# Epoch 10/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.2458
# 4/4 [==============================] - 0s 1ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 2ms/step - loss: 2.4835
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4439
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4186
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4106
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3995
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3710
# Epoch 7/10
# 7/7 [==============================] - 0s 753us/step - loss: 2.3253
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3103
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2865
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2673
# 3/3 [==============================] - 0s 3ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 3ms/step - loss: 2.2846
# Epoch 2/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2808
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2475
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2052
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1946
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1636
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1516
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1393
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1141
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0821
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 5ms/step - loss: 1.4961
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4811
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4761
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4391
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4315
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4282
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4079
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3843
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3928
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3747
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 7ms/step - loss: 1.3729
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4532
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4534
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4275
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4404
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3975
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4024
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3794
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3536
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3616
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 3ms/step - loss: 1.4411
# Epoch 2/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4736
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4650
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4154
# Epoch 5/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4330
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5065
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4341
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3724
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3768
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3671
# 2/2 [==============================] - 0s 0s/step
# Epoch 1/10
# 18/18 [==============================] - 0s 2ms/step - loss: 1.9152
# Epoch 2/10
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2836
# Epoch 3/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.8706
# Epoch 4/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6533
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5552
# Epoch 6/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5023
# Epoch 7/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4783
# Epoch 8/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4544
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4417
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4316
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.9578
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.3281
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.9164
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6792
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5597
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4989
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4617
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4386
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4230
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4148
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 0s 1ms/step - loss: 1.9640
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 1.2679
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.8681
# Epoch 4/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6635
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5568
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.5069
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4747
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4573
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4421
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4302
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5203
# Epoch 2/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6409
# Epoch 3/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4772
# Epoch 4/10
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4236
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4209
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4031
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4036
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4034
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3834
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3761
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7277
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7142
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4441
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4170
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4036
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4089
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3848
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3776
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3710
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3673
# 2/2 [==============================] - 0s 1ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0650
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8079
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4930
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4545
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4190
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4074
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3932
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3861
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3758
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3774
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4231
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4130
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4151
# Epoch 4/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4053
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4191
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4102
# Epoch 7/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4034
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3916
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3968
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4006
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0947
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0897
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0895
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0905
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0824
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0772
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0814
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0897
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0749
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0823
# 2/2 [==============================] - 0s 0s/step
# Epoch 1/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3049
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3109
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2914
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2983
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2949
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2982
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2907
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2948
# Epoch 9/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3000
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3068
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 4ms/step - loss: 2.3036
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0524
# Epoch 3/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.8197
# Epoch 4/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.6081
# Epoch 5/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.4130
# Epoch 6/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.2427
# Epoch 7/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.0927
# Epoch 8/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.9646
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8590
# Epoch 10/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7746
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.8228
# Epoch 2/10
# 7/7 [==============================] - 0s 4ms/step - loss: 2.4522
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1292
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.8426
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5908
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3728
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1868
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0316
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8983
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7993
# 3/3 [==============================] - 0s 8ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 2ms/step - loss: 2.2962
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.0005
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7491
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5273
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3319
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1655
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0252
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9107
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8176
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7443
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.0662
# Epoch 2/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.0646
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0630
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0613
# Epoch 5/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0597
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0581
# Epoch 7/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0565
# Epoch 8/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0548
# Epoch 9/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0532
# Epoch 10/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0516
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3571
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3544
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3515
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3484
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3458
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3431
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3404
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3378
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3350
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3323
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1234
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1214
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1195
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1176
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1158
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1138
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1118
# Epoch 8/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1096
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1077
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1058
# 3/3 [==============================] - 0s 0s/step
# Epoch 1/10
# 18/18 [==============================] - 1s 2ms/step - loss: 0.9456
# Epoch 2/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4304
# Epoch 3/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4247
# Epoch 4/10
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4023
# Epoch 5/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3880
# Epoch 6/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3813
# Epoch 7/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3670
# Epoch 8/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3626
# Epoch 9/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3490
# Epoch 10/10
# 18/18 [==============================] - 0s 1ms/step - loss: 0.3446
# 10/10 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 0.9955
# Epoch 2/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4227
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4052
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3925
# Epoch 5/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3769
# Epoch 6/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3706
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3644
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3609
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3489
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3702
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 19/19 [==============================] - 1s 2ms/step - loss: 1.0532
# Epoch 2/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4515
# Epoch 3/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4317
# Epoch 4/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3989
# Epoch 5/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4126
# Epoch 6/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4072
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.4100
# Epoch 8/10
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3851
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3768
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.3488
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2884
# Epoch 2/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2735
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2587
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2441
# Epoch 5/10
# 4/4 [==============================] - 0s 10ms/step - loss: 2.2295
# Epoch 6/10
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2150
# Epoch 7/10
# 4/4 [==============================] - 0s 872us/step - loss: 2.2007
# Epoch 8/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1865
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1724
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1583
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4166
# Epoch 2/10
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4006
# Epoch 3/10
# 4/4 [==============================] - 0s 0s/step - loss: 2.3847
# Epoch 4/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3689
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3532
# Epoch 6/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3376
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3222
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3068
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2916
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2764
# 2/2 [==============================] - 0s 515us/step
# Epoch 1/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2709
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2600
# Epoch 3/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2491
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2384
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2278
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2171
# Epoch 7/10
# 4/4 [==============================] - 0s 324us/step - loss: 2.2065
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1960
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1854
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1750
# 2/2 [==============================] - 0s 563us/step
# Epoch 1/10
# 6/6 [==============================] - 0s 4ms/step - loss: 2.4224
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2494
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.0904
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.9434
# Epoch 5/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.8074
# Epoch 6/10
# 6/6 [==============================] - 0s 1ms/step - loss: 1.6812
# Epoch 7/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.5652
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4579
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.3600
# Epoch 10/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2707
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1702
# Epoch 2/10
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9602
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7711
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.6132
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4688
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3405
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2386
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1451
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0487
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9786
# 3/3 [==============================] - 0s 3ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5604
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3398
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1225
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9431
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7860
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6397
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5155
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4027
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2946
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2014
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 6/6 [==============================] - 1s 4ms/step - loss: 1.6922
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6577
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4645
# Epoch 4/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4367
# Epoch 5/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4177
# Epoch 6/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.4001
# Epoch 7/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3991
# Epoch 8/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3869
# Epoch 9/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3874
# Epoch 10/10
# 6/6 [==============================] - 0s 1ms/step - loss: 0.3787
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3708
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4974
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4321
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4411
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4186
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3967
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3763
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3977
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3873
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3878
# 3/3 [==============================] - 0s 0s/step
# Epoch 1/10
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7008
# Epoch 2/10
# ...
# Epoch 7/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.7173
# Epoch 8/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6511
# Epoch 9/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6289
# Epoch 10/10
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6000
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4160
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4002
# Epoch 3/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3844
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3689
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3533
# Epoch 6/10
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3379
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3223
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3070
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2918
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2765
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 3ms/step - loss: 2.3995
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3839
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3684
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3530
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3377
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3224
# Epoch 7/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3073
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2921
# Epoch 9/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2771
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2620
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3199
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3039
# Epoch 3/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2881
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2721
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2563
# Epoch 6/10
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2409
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2252
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2098
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1943
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1792
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 5ms/step - loss: 2.2002
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1773
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1386
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1061
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0788
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0367
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0089
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9729
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9476
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9151
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 5ms/step - loss: 2.4944
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4542
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4298
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3956
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3623
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3267
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2991
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2590
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2268
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1921
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4407
# Epoch 2/10
# 4/4 [==============================] - 0s 0s/step - loss: 2.4120
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3730
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3442
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2939
# Epoch 6/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2711
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2333
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1972
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1628
# Epoch 10/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1387
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 5ms/step - loss: 2.6370
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5852
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5335
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4833
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4339
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3853
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3375
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2903
# Epoch 9/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2439
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1985
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/10
# 4/4 [==============================] - 1s 6ms/step - loss: 2.1895
# Epoch 2/10
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1537
# Epoch 3/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1191
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0849
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0507
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0167
# Epoch 7/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9832
# Epoch 8/10
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9497
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9160
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8828
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/10
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3574
# Epoch 2/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3169
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2771
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2370
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1982
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1588
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1207
# Epoch 8/10
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0826
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0440
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0066
# 2/2 [==============================] - 0s 4ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.5059
# Epoch 2/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.4733
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4408
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4085
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3768
# Epoch 6/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.3450
# Epoch 7/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.3139
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2828
# Epoch 9/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.2520
# Epoch 10/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.2216
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2323
# Epoch 2/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1998
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1690
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1388
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1093
# Epoch 6/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0805
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.0527
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0259
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9994
# Epoch 10/10
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9725
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5129
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4788
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4478
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4174
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3886
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3605
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3334
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3061
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2791
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2522
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 6/6 [==============================] - 1s 2ms/step - loss: 2.4352
# Epoch 2/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.2740
# Epoch 3/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.1241
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.9839
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.8519
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.7290
# Epoch 7/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.6138
# Epoch 8/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.5070
# Epoch 9/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4074
# Epoch 10/10
# 6/6 [==============================] - 0s 2ms/step - loss: 1.3162
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.4129
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1539
# Epoch 3/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9293
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7224
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5409
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3914
# Epoch 7/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2617
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1539
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0492
# Epoch 10/10
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9658
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2527
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0572
# Epoch 3/10
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8919
# Epoch 4/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7394
# Epoch 5/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6065
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4717
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3566
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2507
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1627
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0846
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.4619
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4442
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4268
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4095
# Epoch 5/10
# 6/6 [==============================] - 0s 3ms/step - loss: 2.3923
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3753
# Epoch 7/10
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3584
# Epoch 8/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.3417
# Epoch 9/10
# 6/6 [==============================] - 0s 1ms/step - loss: 2.3251
# Epoch 10/10
# 6/6 [==============================] - 0s 696us/step - loss: 2.3086
# 4/4 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6296
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6031
# Epoch 3/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5781
# Epoch 4/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5514
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5262
# Epoch 6/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.4984
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4759
# Epoch 8/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4501
# Epoch 9/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4262
# Epoch 10/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4020
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3294
# Epoch 2/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3088
# Epoch 3/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2865
# Epoch 4/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2635
# Epoch 5/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2420
# Epoch 6/10
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2218
# Epoch 7/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2021
# Epoch 8/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1810
# Epoch 9/10
# 7/7 [==============================] - 0s 2ms/step - loss: 2.1607
# Epoch 10/10
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1394
# 3/3 [==============================] - 0s 2ms/step
# Epoch 1/10
# 28/28 [==============================] - 1s 2ms/step - loss: 0.6603
# Epoch 2/10
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4315
# Epoch 3/10
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4077
# Epoch 4/10
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3996
# Epoch 5/10
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3766
# Epoch 6/10
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3569
# Epoch 7/10
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3565
# Epoch 8/10
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3588
# Epoch 9/10
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3394
# Epoch 10/10
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3317

# %%
print(rnd_search_cv.best_params_)
best_model = rnd_search_cv.best_estimator_
print(best_model)
# Out:
# {'optimizer__learning_rate': 0.01, 'optimizer': 'adam', 'model__hidden_layer_sizes': (100, 90), 'model__dropout': 0, 'loss': 'sparse_categorical_crossentropy', 'epochs': 10, 'batch_size': 20}
# KerasClassifier(
# 	model=<function build_clf at 0x000001FD61145900>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=adam
# 	loss=sparse_categorical_crossentropy
# 	metrics=None
# 	batch_size=20
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=10
# 	hidden_layer_sizes=64
# 	dropout=0.5
# 	optimizer__learning_rate=0.01
# 	model__hidden_layer_sizes=(100, 90)
# 	model__dropout=0
# 	class_weight=None
# )

# %%
c_matrix = confusion_matrix(y_test, rnd_search_cv.predict(X_test))
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"keras", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])
performance
# Out:
# 12/12 [==============================] - 0s 1ms/step
#                  model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.772532   0.803571  0.743802  0.772532
# 0                  SVM  0.519313   0.519313  1.000000  0.683616
# 0        Decision tree  0.738197   0.720588  0.809917  0.762646
# 0                  MLP  0.519313   0.519313  1.000000  0.683616
# 0                keras  0.785408   0.798319  0.785124  0.791667

# %% [markdown]
# ### Discussion of Result

# %% [markdown]
# The aim of this project was to develop a binary classifier that could predict whether an individual has heart disease or not. To achieve this, different modeling techniques, namely logistic regression, SVM, decision tree,MLP and keras technique were used. The primary goal was to select the model that minimized false negatives (i.e., a sick person being wrongly classified as healthy), as this had severe consequences. Additionally, high accuracy values were desirable, particularly true positives, given the evenly split data.
#
# After comparing the five models, it was determined that the SVM model has the best recall score among all the models, indicating less false negative predictions, but the SVM model had a lower precision and accuracy score than the other models indicating less accurate identification of true positives.
#
# The MLP modelling techique also has a good recall score of 1.0000, accuracy of 0.519313, precision of 0.519313 and F1 score of 0.683616.The keras techique has a precision of 0.798319, the Accuracy is 0.785408, Recall of 0.785124 and F1 of 0.791667.
#
# Both MLP and Keras modelling technique performed good.However, the decision tree model has a higher recall score of 0.809917, indicating fewer false negatives. It also has a good accuracy score of 0.738197 in this case high true positive gives indication of a good model.
#
# Given the context of the data, model with high recall and accuracy should be selected, as the cost of false negatives is higher than that of false positives and it is also important to determine the true positives accurately(people with heart disease classified as sick). Decision tree would be the best fit model for this data, as it has a good recall score, as well as a good accuracy score.

# %% [markdown]
# ######
